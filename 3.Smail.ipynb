# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('spam.csv', encoding='latin-1')

# %%
df
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# ...         ...        ...
# 5567        NaN        NaN
# 5568        NaN        NaN
# 5569        NaN        NaN
# 5570        NaN        NaN
# 5571        NaN        NaN
#
# [5572 rows x 5 columns]

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.tail()
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 5567        NaN        NaN
# 5568        NaN        NaN
# 5569        NaN        NaN
# 5570        NaN        NaN
# 5571        NaN        NaN

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
data = df.where((pd.notnull(df)),'')

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
x = df['v2']
y=df['v1']

# %%
print(x)
# Out:
# 0       Go until jurong point, crazy.. Available only ...
# 1                           Ok lar... Joking wif u oni...
# 2       Free entry in 2 a wkly comp to win FA Cup fina...
# 3       U dun say so early hor... U c already then say...
# 4       Nah I don't think he goes to usf, he lives aro...
#                               ...
# 5567    This is the 2nd time we have tried 2 contact u...
# 5568                Will Ì_ b going to esplanade fr home?
# 5569    Pity, * was in mood for that. So...any other s...
# 5570    The guy did some bitching but I acted like i'd...
# 5571                           Rofl. Its true to its name
# Name: v2, Length: 5572, dtype: object

# %%
print(y)
# Out:
# 0        ham
# 1        ham
# 2       spam
# 3        ham
# 4        ham
#         ...
# 5567    spam
# 5568     ham
# 5569     ham
# 5570     ham
# 5571     ham
# Name: v1, Length: 5572, dtype: object

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2)

# %%
feature_extraction = TfidfVectorizer(min_df=1, stop_words='english', lowercase=True)

x_train_features = feature_extraction.fit_transform(x_train)
x_test_features = feature_extraction.transform(x_test)

y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.transform(y_test)

# %%
print(x_train_features)
# Out:
#   (0, 3174)	0.5172785105862271
#   (0, 3089)	0.35891576959687765
#   (0, 2615)	0.6276615630641856
#   (0, 4064)	0.4578682944605345
#   (1, 3089)	0.18500469998567784
#   (1, 2237)	0.27499418105951157
#   (1, 7341)	0.22349125426902172
#   (1, 4756)	0.22017619837161817
#   (1, 4761)	0.1765117093519852
#   (1, 3094)	0.3183272355283333
#   (1, 4039)	0.17980104330034832
#   (1, 2790)	0.35415414742132045
#   (1, 5424)	0.2596059848895515
#   (1, 6698)	0.18696857967503497
#   (1, 7134)	0.278838345298008
#   (1, 2137)	0.36686394668248457
#   (1, 4379)	0.2768744656086508
#   (1, 4632)	0.2191242434736431
#   (1, 6025)	0.24923076742907557
#   (2, 4588)	0.42427913305758364
#   (2, 6301)	0.2853604784471494
#   (2, 3076)	0.27107122885777407
#   (2, 1254)	0.37702349029786547
#   (2, 4197)	0.3072035663721653
#   (2, 2937)	0.41900869346903646
#   :	:
#   (4454, 7421)	0.2184694826641869
#   (4454, 3305)	0.2184694826641869
#   (4454, 3654)	0.2184694826641869
#   (4454, 5892)	0.2184694826641869
#   (4454, 7013)	0.2184694826641869
#   (4454, 6847)	0.2184694826641869
#   (4455, 6301)	0.16495803814824467
#   (4455, 3320)	0.16626715150838495
#   (4455, 3500)	0.1819981280141287
#   (4455, 305)	0.18528316393604743
#   (4455, 3364)	0.15746745124926353
#   (4455, 6596)	0.3128901029948199
#   (4455, 1848)	0.18765795205569089
#   (4455, 1159)	0.18586193254737676
#   (4455, 7151)	0.2078724785436541
#   (4455, 1697)	0.20005917319643338
#   (4455, 4070)	0.2664862674813859
#   (4455, 7083)	0.290756610676982
#   (4455, 3734)	0.27287020278322177
#   (4455, 758)	0.30495385132603864
#   (4455, 7408)	0.30495385132603864
#   (4455, 6304)	0.30495385132603864
#   (4455, 100)	0.30495385132603864
#   (4456, 2390)	0.6772211167491541
#   (4456, 4808)	0.7357795587192053

# %% [markdown]
# **Model Training**

# %%
model = LogisticRegression()
model.fit(x_train_features, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# **Model Evaluation**

# %%
predicted_labels = model.predict(x_train_features)

# %% [markdown]
# **Accuracy**

# %%
accuracy = accuracy_score(y_train, predicted_labels)
str(round(accuracy*100, 2))+"%"
# Out:
# '97.04%'

# %% [markdown]
# **Classification Report**

# %%
report = classification_report(y_train, predicted_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      3856
#            1       1.00      0.78      0.88       601
#
#     accuracy                           0.97      4457
#    macro avg       0.98      0.89      0.93      4457
# weighted avg       0.97      0.97      0.97      4457

# %% [markdown]
# **Confusion Matrix**

# %%
matrix = confusion_matrix(y_train, predicted_labels)
print(matrix)
# Out:
# [[3854    2]
#  [ 130  471]]

# %% [markdown]
# **Use Model**

# %%
prediction = model.predict(x_test_features)
if prediction[0] == 0:
  print("Ham")
else:
  print("Spam")
# Out:
# Ham

# %%
mail = input("Enter the mail")
mail_features = feature_extraction.transform([mail])
prediction = model.predict(mail_features)
if prediction[0] == 0:
  print("Ham")
else:
  print("Spam")
# Out:
# Enter the mailcongratulations! you won a cash prize of XXX Rs.
# Spam
